# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Importing nessessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from statistics import *
from tabulate import tabulate

# %% [markdown]
# ### loading the data into pandas dataframe
#
# ## Step 1) Variable Identification

# %%
df = pd.read_csv('../data/Week1_challenge_data_source(CSV).csv', na_values=['?', None])
df.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %% [markdown]
# ## Step 2) Data Understanding

# %%
df.size
# Out:
# 8250055

# %%
df.shape
# Out:
# (150001, 55)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
df.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...

# %%
df['Bearer Id'].mode()
# Out:
# 0    1.304243e+19
# dtype: float64

# %%
# Count of unique values of a column

print('\nNumber of unique values => ' + str(len(df['Bearer Id'].unique())))
print('\nNumber of unique values => ' + str(len(df['IMSI'].unique())))
print('\nNumber of unique values => ' + str(len(df['MSISDN/Number'].unique())))
# Out:
# Number of unique values => 134709
#
# Number of unique values => 107266
#
# Number of unique values => 106857

# %%
# List of all unique values of a column

print('\nUnique values are => \n\n' + str(pd.Series(df['MSISDN/Number'].unique()).sort_values(ascending=True)))
# Out:
# Unique values are =>
#
# 34600    3.360100e+10
# 94576    3.360100e+10
# 99079    3.360100e+10
# 73278    3.360101e+10
# 13613    3.360101e+10
#              ...
# 47259    3.379000e+10
# 76514    3.197021e+12
# 93633    3.370000e+14
# 93065    8.823971e+14
# 226               NaN
# Length: 106857, dtype: float64

# %%
# Frequency Distribution of unique values of a column

print('\nFrequency distribution of unique values => \n\n'+ str(df['MSISDN/Number'].value_counts(dropna=False).sort_values(ascending = False)))
# Out:
# Frequency distribution of unique values =>
#
# NaN             1066
# 3.362632e+10      18
# 3.361489e+10      17
# 3.362578e+10      17
# 3.365973e+10      16
#                 ...
# 3.366364e+10       1
# 3.366742e+10       1
# 3.366556e+10       1
# 3.376148e+10       1
# 3.366483e+10       1
# Name: MSISDN/Number, Length: 106857, dtype: int64

# %%
# Distinct value counts/frequencies of each column to determine if there are any columns with only a single value/all different values

pd.DataFrame(df.apply(lambda x: len(x.value_counts(dropna=False)), axis=0), columns=['Unique Value Count']).sort_values(by='Unique Value Count', ascending=True)
# Out:
#                                           Unique Value Count
# UL TP > 300 Kbps (%)                                      64
# 50 Kbps < UL TP < 300 Kbps (%)                            69
# 250 Kbps < DL TP < 1 Mbps (%)                             74
# 50 Kbps < DL TP < 250 Kbps (%)                            85
# 10 Kbps < UL TP < 50 Kbps (%)                             86
# DL TP > 1 Mbps (%)                                        86
# UL TP < 10 Kbps (%)                                       99
# DL TP < 50 Kbps (%)                                      101
# Handset Manufacturer                                     171
# Avg RTT UL (ms)                                          723
# Start ms                                                1001
# End ms                                                  1001
# Nb of sec with 37500B < Vol UL                          1105
# Handset Type                                            1397
# ...

# %%
def find_min_max_in(df, col):
    """
    The function takes in a column and returns the top 5
    and bottom 5 in dataframe in that column.
    args:
        col: string - column name
    return:
        info_df: dataframe - final 5 dataframe
    """
    top = df[col].idxmax()
    top_df = pd.DataFrame(df.loc[top])
    bottom = df[col].idxmin()
    bottom_df = pd.DataFrame(df.loc[bottom])
    info_df = pd.concat([top_df, bottom_df], axis=1)
    return info_df

find_min_max_in(df, 'Total DL (Bytes)')

# This usually is helpful to understand various attributes of max and min values of a particular column. 
# This can also help to decide which column to keep for further analysis.
# Out:
#                                                                 61396  \
# Bearer Id                                                 7.34988e+18
# Start                                                  4/26/2019 4:36
# Start ms                                                           42
# End                                                    4/27/2019 3:30
# End ms                                                            336
# Dur. (ms)                                                       82424
# IMSI                                                      2.08202e+14
# MSISDN/Number                                             3.37813e+10
# IMEI                                                      3.57654e+13
# Last Location Name                                            D61328C
# Avg RTT DL (ms)                                                   NaN
# Avg RTT UL (ms)                                                   NaN
# ...

# %% [markdown]
# ## Step 3) Data Cleaning/Manipulation

# %% [markdown]
# #### Fixing Columns
# ##### Dropping Columns with Single Value

# %%
db_single=df.copy()

single_value_columns = pd.DataFrame(db_single.apply(lambda x: len(x.value_counts()), axis=0), columns=['SingleValueColumn'])

drop_single_value_columns = list(single_value_columns.loc[single_value_columns['SingleValueColumn']==1].index)

print('Columns which have just a single value => \n\n' + str(drop_single_value_columns))

df.drop(drop_single_value_columns, axis=1, inplace=True)

print('\n\nRemaining Columns => ' + str(len(df.columns)))
# Out:
# Columns which have just a single value =>
#
# []
#
#
# Remaining Columns => 55

# %% [markdown]
# #### Dropping Columns with All Different Values

# %%
db_diff=df.copy()

alldiff_value_columns = pd.DataFrame(db_diff.apply(lambda x: len(x.value_counts()), axis=0), columns=['AllDiffValueColumn'])

drop_alldiff_value_columns = list(alldiff_value_columns.loc[alldiff_value_columns['AllDiffValueColumn']==len(df.index)].index)

print('Columns which have all values different => \n\n' + str(drop_alldiff_value_columns))

df.drop(drop_alldiff_value_columns, axis=1, inplace=True)

print('\n\nRemaining Columns => ' + str(len(df.columns)))
# Out:
# Columns which have all values different =>
#
# []
#
#
# Remaining Columns => 55

# %% [markdown]
# #### Duplicate Data

# %%
# Count of duplicates
df.duplicated().value_counts()
# Drop duplicates
df.drop_duplicates(keep='first', inplace=True)
df.drop_duplicates(subset=['MSISDN/Number'], keep='first', inplace=True)

# %% [markdown]
# #### Missing Values

# %%
# Any missing values
df.isnull().values.any()

# Total number of missing values
df.isnull().sum().sum()

############### Column Wise ###############
df.isna().sum() # Count of nulls in each column
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...
